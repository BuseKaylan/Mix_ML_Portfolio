# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('coronary_prediction.csv')

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.dropna()
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.dropna(how='all')
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3656 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             3656 non-null   int64
#  1   age              3656 non-null   int64
#  2   education        3656 non-null   float64
#  3   currentSmoker    3656 non-null   int64
#  4   cigsPerDay       3656 non-null   float64
#  5   BPMeds           3656 non-null   float64
#  6   prevalentStroke  3656 non-null   int64
#  7   prevalentHyp     3656 non-null   int64
#  8   diabetes         3656 non-null   int64
#  9   totChol          3656 non-null   float64
#  10  sysBP            3656 non-null   float64
#  11  diaBP            3656 non-null   float64
#  12  BMI              3656 non-null   float64
#  13  heartRate        3656 non-null   float64
#  14  glucose          3656 non-null   float64
#  15  TenYearCHD       3656 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
X = df.drop('TenYearCHD',axis =1)
y = df['TenYearCHD']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc = DecisionTreeClassifier()

# %%
dc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(pred, y_test))
# Out:
# [[792 123]
#  [136  46]]

# %%
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       915
#            1       0.27      0.25      0.26       182
#
#     accuracy                           0.76      1097
#    macro avg       0.56      0.56      0.56      1097
# weighted avg       0.76      0.76      0.76      1097

# %%
from sklearn import tree

# %%
tree.plot_tree(dc, filled=True)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'max_depth':[2,4,6,8,10,12], 'min_samples_split' : [2,3,4], 'min_samples_leaf':[1,2]}
clf = tree.DecisionTreeClassifier()

# %%
gcv = GridSearchCV(estimator=clf, param_grid = params)
gcv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 4, 6, 8, 10, 12],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3, 4]})

# %%
model= gcv.best_estimator_
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
tree.plot_tree(model, filled=True)
plt.show()

# %%
#randomforest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 50)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
predi = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(confusion_matrix(predi, y_test))
# Out:
# [[920 162]
#  [  8   7]]

# %%
print(classification_report(predi, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.85      0.92      1082
#            1       0.04      0.47      0.08        15
#
#     accuracy                           0.85      1097
#    macro avg       0.52      0.66      0.50      1097
# weighted avg       0.98      0.85      0.90      1097

# %%
print(accuracy_score(predi, y_test))
# Out:
# 0.845031905195989

# %%
dc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dc.predict(X_test)

# %%
prun = dc.cost_complexity_pruning_path(X_train, y_train)

# %%
alphas = prun['ccp_alphas']

# %%
train_accuracy, test_accuracy = [],[]

for j in alphas:
    tre = DecisionTreeClassifier(ccp_alpha=j)
    tre.fit(X_train,y_train)
    y_train_pred= tre.predict(X_train)
    y_test_pred = tre.predict(X_test)
    
    train_accuracy.append(accuracy_score(y_train, y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_test_pred))

# %%
sns.set()
plt.figure(figsize=(10,6))

sns.lineplot(y=train_accuracy, x=alphas, label = 'training accuracy')
sns.lineplot(y=test_accuracy, x = alphas, label = 'test accuracy')
plt.show()

# %%
clf = DecisionTreeClassifier(random_state=0, ccp_alpha = 0.03)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.03, random_state=0)

# %%
predict = clf.predict(X_test)

# %%
print(accuracy_score(y_test, predict))
# Out:
# 0.845943482224248

# %%
df1 = pd.read_csv('winequality-red.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
X = df1.drop('quality', axis=1)
y = df1['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
dtc =DecisionTreeClassifier()

# %%
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction = dtc.predict(X_test)

# %%
print(confusion_matrix(y_test, prediction))
# Out:
# [[  0   0   0   0   1   0]
#  [  0   3   9   4   2   0]
#  [  3   5 131  55   7   1]
#  [  0   4  47 113  26   4]
#  [  0   0   8  11  40   0]
#  [  0   0   0   2   3   1]]

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.25      0.17      0.20        18
#            5       0.67      0.65      0.66       202
#            6       0.61      0.58      0.60       194
#            7       0.51      0.68      0.58        59
#            8       0.17      0.17      0.17         6
#
#     accuracy                           0.60       480
#    macro avg       0.37      0.37      0.37       480
# weighted avg       0.60      0.60      0.60       480

# %%
print(accuracy_score(y_test, prediction))
# Out:
# 0.6

# %%
tree.plot_tree(dtc, filled =True)
plt.show()

# %%
#pre-pruning

# %%
param_grid = {'max_depth': [2,4,6,8,10,12], 'min_samples_split':[2,3,4,5], 'min_samples_leaf':[1,2,3,4,5,6,7,8]}
gcv1 = GridSearchCV(estimator = dtc, param_grid = param_grid)
gcv1.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 4, 6, 8, 10, 12],
#                          'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7, 8],
#                          'min_samples_split': [2, 3, 4, 5]})

# %%
model1 = gcv1.best_estimator_

# %%
model1.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=12, min_samples_leaf=4, min_samples_split=5)

# %%
tree.plot_tree(model, filled=True)
plt.show()

# %%
#post-pruning

# %%
prun = dtc.cost_complexity_pruning_path(X_train, y_train)

# %%
alphas = prun['ccp_alphas']

# %%
train_accuracy, test_accuracy = [],[]

for i in alphas:
    dc = DecisionTreeClassifier(ccp_alpha=i)
    dc.fit(X_train, y_train)
    y_train_pred = dc.predict(X_train)
    y_test_pred = dc.predict(X_test)
    
    train_accuracy.append(accuracy_score(y_train, y_train_pred))
    test_accuracy.append(accuracy_score(y_test, y_test_pred))

# %%
sns.set()
plt.figure(figsize=(10,6))

sns.lineplot(y=train_accuracy, x = alphas, label='train accuracy')
sns.lineplot(y = test_accuracy, x = alphas, label = 'test accuracy')
plt.show()

# %%
dc = DecisionTreeClassifier(random_state= 0, ccp_alpha=0.002)

# %%
dc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.002, random_state=0)

# %%
predii = dc.predict(X_test)

# %%
print("Training Accuracy: ", dc.score(X_train, y_train))
print("Test Accuracy: ", accuracy_score(y_test, predii))
# Out:
# Training Accuracy:  0.8471849865951743
# Test Accuracy:  0.5958333333333333
